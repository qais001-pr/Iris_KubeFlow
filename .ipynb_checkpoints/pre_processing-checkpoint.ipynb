# %%
pip install kfp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from kfp import dsl
from kfp import compiler
print("Import Dependencies")
# Out:
# Import Dependencies

# %%
pip install scikit-learn pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from kfp import dsl
from kfp import compiler


# ============================================================
# COMPONENT 1 — LOAD IRIS DATA
# ============================================================

@dsl.component(
    base_image="tensorflow/tensorflow:2.16.1",
    packages_to_install=[
        "scikit-learn",
        "numpy",
        "pandas"
    ]
)
def load_iris_data(
    X_output: dsl.Output[dsl.Dataset],
    y_output: dsl.Output[dsl.Dataset]
):

    import os
    import numpy as np
    from sklearn.datasets import load_iris

    print("=" * 60)
    print("LOAD IRIS DATA COMPONENT STARTED")
    print("=" * 60)

    print("\nLoading Iris dataset...")

    iris = load_iris()

    print("Dataset loaded successfully")

    print("X shape:", iris.data.shape)
    print("y shape:", iris.target.shape)

    print("Classes:", iris.target_names)

    # --------------------------------------------------------
    # Save X
    # --------------------------------------------------------

    print("\nSaving X dataset...")

    np.save(
        X_output.path,
        iris.data
    )

    print(
        "X saved:",
        X_output.path
    )

    # --------------------------------------------------------
    # Save y
    # --------------------------------------------------------

    print("\nSaving y dataset...")

    np.save(
        y_output.path,
        iris.target
    )

    print(
        "y saved:",
        y_output.path
    )

    print("\nChecking files...")

    print(
        "X exists:",
        os.path.exists(X_output.path)
    )

    print(
        "Y exists:",
        os.path.exists(y_output.path)
    )

    print("\n" + "=" * 60)
    print("LOAD IRIS DATA COMPLETED")
    print("=" * 60)


# ============================================================
# COMPONENT 2 — TRAIN TENSORFLOW MODEL
# ============================================================

@dsl.component(
    base_image="tensorflow/tensorflow:2.16.1",
    packages_to_install=[
        "scikit-learn",
        "numpy",
        "pandas"
    ]
)
def train_iris_model(
    X_input: dsl.Input[dsl.Dataset],
    y_input: dsl.Input[dsl.Dataset],
    model_output: dsl.Output[dsl.Model]
):

    import os
    import numpy as np
    import tensorflow as tf

    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler

    print("=" * 60)
    print("TENSORFLOW TRAINING COMPONENT STARTED")
    print("=" * 60)

    # --------------------------------------------------------
    # Load dataset
    # --------------------------------------------------------

    print("\n[1] Loading datasets")

    X = np.load(
        X_input.path
    )

    y = np.load(
        y_input.path
    )

    print("X shape:", X.shape)
    print("y shape:", y.shape)

    # --------------------------------------------------------
    # Train/Test split
    # --------------------------------------------------------

    print("\n[2] Splitting dataset")

    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.20,
        random_state=42,
        stratify=y
    )

    print("X_train:", X_train.shape)
    print("X_test:", X_test.shape)

    # --------------------------------------------------------
    # Scaling
    # --------------------------------------------------------

    print("\n[3] Scaling features")

    scaler = StandardScaler()

    X_train = scaler.fit_transform(
        X_train
    )

    X_test = scaler.transform(
        X_test
    )

    print("Scaling completed")

    # --------------------------------------------------------
    # TensorFlow model
    # --------------------------------------------------------

    print("\n[4] Creating TensorFlow model")

    model = tf.keras.Sequential([

        tf.keras.layers.Input(
            shape=(4,)
        ),

        tf.keras.layers.Dense(
            16,
            activation="relu"
        ),

        tf.keras.layers.Dense(
            8,
            activation="relu"
        ),

        tf.keras.layers.Dense(
            3,
            activation="softmax"
        )
    ])

    # --------------------------------------------------------
    # Compile
    # --------------------------------------------------------

    print("\n[5] Compiling model")

    model.compile(

        optimizer=tf.keras.optimizers.Adam(
            learning_rate=0.001
        ),

        loss="sparse_categorical_crossentropy",

        metrics=[
            "accuracy"
        ]
    )

    model.summary()

    # --------------------------------------------------------
    # Train
    # --------------------------------------------------------

    print("\n[6] Starting training")

    history = model.fit(

        X_train,

        y_train,

        validation_data=(
            X_test,
            y_test
        ),

        epochs=30,

        batch_size=16,

        verbose=1
    )

    print("\nTraining completed")

    # --------------------------------------------------------
    # Evaluate
    # --------------------------------------------------------

    print("\n[7] Evaluating model")

    loss, accuracy = model.evaluate(
        X_test,
        y_test,
        verbose=0
    )

    print("Test Loss:", loss)
    print("Test Accuracy:", accuracy)

    # --------------------------------------------------------
    # Save model
    # --------------------------------------------------------

    print("\n[8] Saving TensorFlow model")

    model_output.metadata["accuracy"] = float(
        accuracy
    )

    model_output.metadata["framework"] = "tensorflow"

    model_output.metadata["dataset"] = "iris"

    model.export(
        model_output.path
    )

    print(
        "Model saved to:",
        model_output.path
    )

    print("\n" + "=" * 60)
    print("TENSORFLOW TRAINING COMPLETED")
    print("=" * 60)


# ============================================================
# PIPELINE
# ============================================================

@dsl.pipeline(
    name="iris-tensorflow-pipeline",
    description="End-to-end Iris classification using TensorFlow"
)
def iris_tensorflow_pipeline():

    # --------------------------------------------------------
    # Load data
    # --------------------------------------------------------

    data_task = load_iris_data()

    # --------------------------------------------------------
    # Train model
    # --------------------------------------------------------

    train_task = train_iris_model(

        X_input=data_task.outputs["X_output"],

        y_input=data_task.outputs["y_output"]
    )


# ============================================================
# COMPILE PIPELINE
# ============================================================

compiler.Compiler().compile(

    pipeline_func=iris_tensorflow_pipeline,

    package_path="iris-tensorflow-pipeline.yaml"
)

print("=" * 60)
print("PIPELINE COMPILED SUCCESSFULLY")
print("=" * 60)

print(
    "YAML file:",
    "iris-tensorflow-pipeline.yaml"
)
# Out:
# ...
# PIPELINE COMPILED SUCCESSFULLY
# ...
# YAML file: iris-tensorflow-pipeline.yaml
